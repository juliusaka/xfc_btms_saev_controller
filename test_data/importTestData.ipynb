# %% [markdown]
# # import Test Data
#
# this need to be ran to import the Beam-Simulation results to the stand-alone version of the controller simulation or to the visualize input data notebook

# %%
import pandas as pd
import numpy as np
#import matplotlib
import time
from dask import dataframe as df1
import dask
path = "C:/Users/akaju/Documents/project thesis/Beam Output Data/vehicletypes-Base_2035_20210204_updated.csv"

# %%
print("\n loading vehicletypes file from "+ path + "\n")

dtype={'automationLevel': 'float64',
       'primaryFuelCapacityInJoule': 'float64',
       'primaryFuelConsumptionInJoulePerMeter': 'float64',
       'secondaryFuelType': 'string',
       'secondaryVehicleEnergyFile': 'string'}
usecols = ['vehicleTypeId', 'primaryFuelType',
       'primaryFuelConsumptionInJoulePerMeter', 'primaryFuelCapacityInJoule',
       'secondaryFuelType','secondaryFuelConsumptionInJoulePerMeter',
       'rechargeLevel2RateLimitInWatts','rechargeLevel3RateLimitInWatts',
       'vehicleCategory','sampleProbabilityWithinCategory', 
       'sampleProbabilityString', 'chargingCapability', 'RH_prob']
#all columns : ['vehicleTypeId', 'seatingCapacity', 'standingRoomCapacity', 'lengthInMeter', 'primaryFuelType',
    #    'primaryFuelConsumptionInJoulePerMeter', 'primaryFuelCapacityInJoule',
    #    'primaryVehicleEnergyFile', 'secondaryFuelType',
    #    'secondaryFuelConsumptionInJoulePerMeter', 'secondaryVehicleEnergyFile',
    #    'secondaryFuelCapacityInJoule', 'automationLevel', 'maxVelocity',
    #    'passengerCarUnit', 'rechargeLevel2RateLimitInWatts',
    #    'rechargeLevel3RateLimitInWatts', 'vehicleCategory',
    #    'sampleProbabilityWithinCategory', 'sampleProbabilityString',
    #    'chargingCapability', 'RH_prob']
df_vehicles = df1.read_csv(path, dtype = dtype, usecols = usecols)

df_vehicles.head(10)
# Out:
#  loading vehicletypes file from C:/Users/akaju/Documents/project thesis/Beam Output Data/vehicletypes-Base_2035_20210204_updated.csv
#                                        vehicleTypeId primaryFuelType  \
# 0      ev-L1-0-to-50000-LowTech-2035-Car-BEV_200_XFC     electricity
# 1  ev-L1-0-to-50000-LowTech-2035-Midsize-BEV_200_XFC     electricity
# 2      ev-L1-0-to-50000-LowTech-2035-Car-BEV_300_XFC     electricity
# 3      ev-L1-0-to-50000-LowTech-2035-SUV-BEV_200_XFC     electricity
# 4  ev-L1-0-to-50000-LowTech-2035-Midsize-BEV_300_XFC     electricity
# 5      ev-L1-0-to-50000-LowTech-2035-SUV-BEV_300_XFC     electricity
# 6   ev-L1-0-to-50000-LowTech-2035-Pickup-BEV_200_XFC     electricity
# 7   ev-L1-0-to-50000-LowTech-2035-Pickup-BEV_300_XFC     electricity
# 8          ev-L1-0-to-50000-LowTech-2035-Car-BEV_200     electricity
# 9      ev-L1-0-to-50000-LowTech-2035-Midsize-BEV_200     electricity
#
#    primaryFuelConsumptionInJoulePerMeter  primaryFuelCapacityInJoule  \
# 0                                  626.0                 201489368.0
# 1                                  626.0                 201489368.0
# 2                                  626.0                 302234052.0
# 3                                  626.0                 201489368.0
# 4                                  626.0                 302234052.0
# 5                                  626.0                 302234052.0
# 6                                  626.0                 201489368.0
# 7                                  626.0                 302234052.0
# 8                                  626.0                 201489368.0
# 9                                  626.0                 201489368.0
#
#   secondaryFuelType  secondaryFuelConsumptionInJoulePerMeter  \
# 0              <NA>                                      NaN
# 1              <NA>                                      NaN
# 2              <NA>                                      NaN
# 3              <NA>                                      NaN
# 4              <NA>                                      NaN
# 5              <NA>                                      NaN
# 6              <NA>                                      NaN
# 7              <NA>                                      NaN
# 8              <NA>                                      NaN
# 9              <NA>                                      NaN
#
#    rechargeLevel2RateLimitInWatts  rechargeLevel3RateLimitInWatts  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# 5                             NaN                             NaN
# 6                             NaN                             NaN
# 7                             NaN                             NaN
# 8                             NaN                             NaN
# 9                             NaN                             NaN
#
#   vehicleCategory  sampleProbabilityWithinCategory  \
# 0             Car                         0.010392
# 1             Car                         0.010541
# 2             Car                         0.024939
# 3             Car                         0.011877
# 4             Car                         0.011158
# 5             Car                         0.018669
# 6             Car                         0.003785
# 7             Car                         0.006257
# 8             Car                         0.004517
# 9             Car                         0.003628
#
#                              sampleProbabilityString chargingCapability  \
# 0  ridehail | all:0.0; income | 0-50:0.0103922049...      XFC(400.0|DC)
# 1  ridehail | all:0.0; income | 0-50:0.0105413362...      XFC(400.0|DC)
# 2  ridehail | all:0.0; income | 0-50:0.0249388435...      XFC(400.0|DC)
# 3  ridehail | all:0.0; income | 0-50:0.0118769474...      XFC(400.0|DC)
# 4  ridehail | all:0.04690657401315327; income | 0...      XFC(400.0|DC)
# 5  ridehail | all:0.0; income | 0-50:0.0186688996...      XFC(400.0|DC)
# 6  ridehail | all:0.0; income | 0-50:0.0037848101...      XFC(400.0|DC)
# 7  ridehail | all:0.0; income | 0-50:0.0062568286...      XFC(400.0|DC)
# 8  ridehail | all:0.0; income | 0-50:0.0045167413...       FC(150.0|DC)
# 9  ridehail | all:0.0; income | 0-50:0.0036279348...       FC(150.0|DC)
#
#     RH_prob
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.046907
# 5  0.000000
# 6  0.000000
# 7  0.000000
# 8  0.000000
# 9  0.000000

# %%
path = "C:/Users/akaju/Documents/project thesis/Beam Output Data/archive/0.events.csv/0.events.csv"
# for testing
#path = 'test_data/beam1/beam_output20-006.csv'
print("\n loading simulation results file from "+ path + "\n")
all_cols = ['person', 'link', 'facility', 'actType', 'time', 'type', 'departTime',
       'startX', 'startY', 'endX', 'endY', 'driver', 'vehicle', 'parkingTaz',
       'chargingPointType', 'pricingModel', 'parkingType', 'locationY',
       'locationX', 'cost', 'legMode', 'primaryFuelLevel',
       'secondaryFuelLevel', 'price', 'score', 'mode', 'currentTourMode',
       'expectedMaximumUtility', 'availableAlternatives', 'location',
       'personalVehicleAvailable', 'length', 'tourIndex', 'vehicleType',
       'links', 'numPassengers', 'primaryFuel', 'riders', 'toStopIndex',
       'fromStopIndex', 'seatingCapacity', 'tollPaid', 'capacity',
       'arrivalTime', 'departureTime', 'linkTravelTime', 'secondaryFuel',
       'secondaryFuelType', 'primaryFuelType', 'shiftStatus', 'parkingZoneId',
       'fuel', 'duration', 'incentive', 'tollCost', 'netCost', 'reason']
usecols = ['time', 'type', 'vehicle', 'parkingTaz',
       'chargingPointType', 'primaryFuelLevel', 'mode', 'currentTourMode', 'vehicleType', 'arrivalTime',
       'departureTime', 'linkTravelTime', 'primaryFuelType', 
       'parkingZoneId', 'fuel', 'duration' ]
       # vehicle seems like it is the vehicle identifier
       # , 'primaryFuel' doesnt seem needed
       # departTime doesnt seem used, discarded
dtype = {
       'time': 'int64', 
       'type': 'category', 
       'vehicle': 'string', 
       'parkingTaz': 'category', #
       'chargingPointType': 'category', 
       'primaryFuelLevel': 'float64', #
       'mode': 'category', 
       'currentTourMode': 'category', 
       'vehicleType': 'category', 
       'arrivalTime': 'float64', #
       'departureTime': 'float64', # 
       'linkTravelTime': 'string', 
       'primaryFuelType': 'category', 
       'parkingZoneId': 'category',
       'duration': 'float64' #
}
df_sim = df1.read_csv(path, dtype = dtype, usecols = usecols) #, blocksize = 12e6)

#df_sim.head(20)
# Out:
#  loading simulation results file from C:/Users/akaju/Documents/project thesis/Beam Output Data/archive/0.events.csv/0.events.csv

# %%
df_sim.head(10)
# Out:
#    time                 type                                vehicle  \
# 0     0            departure                                   <NA>
# 1     0            departure                                   <NA>
# 2     0  PersonEntersVehicle            ST:9559766-124-C-Weekday-52
# 3     0  PersonEntersVehicle                             SF:7586255
# 4     0            departure                                   <NA>
# 5     0  PersonEntersVehicle                SO:t_148106_b_2690_tn_0
# 6     0            departure                                   <NA>
# 7     0  PersonEntersVehicle  GG:5192961-16MARCH-01-WKDY-Weekday-05
# 8     0            departure                                   <NA>
# 9     0  PersonEntersVehicle                             SF:7600736
#
#   parkingTaz chargingPointType  primaryFuelLevel mode currentTourMode  \
# 0        NaN               NaN               NaN  NaN             NaN
# 1        NaN               NaN               NaN  NaN             NaN
# 2        NaN               NaN               NaN  NaN             NaN
# 3        NaN               NaN               NaN  NaN             NaN
# 4        NaN               NaN               NaN  NaN             NaN
# 5        NaN               NaN               NaN  NaN             NaN
# 6        NaN               NaN               NaN  NaN             NaN
# 7        NaN               NaN               NaN  NaN             NaN
# 8        NaN               NaN               NaN  NaN             NaN
# 9        NaN               NaN               NaN  NaN             NaN
#
#   vehicleType  arrivalTime  departureTime linkTravelTime primaryFuelType  \
# 0         NaN          NaN            NaN           <NA>             NaN
# 1         NaN          NaN            NaN           <NA>             NaN
# 2         NaN          NaN            NaN           <NA>             NaN
# 3         NaN          NaN            NaN           <NA>             NaN
# 4         NaN          NaN            NaN           <NA>             NaN
# 5         NaN          NaN            NaN           <NA>             NaN
# 6         NaN          NaN            NaN           <NA>             NaN
# 7         NaN          NaN            NaN           <NA>             NaN
# 8         NaN          NaN            NaN           <NA>             NaN
# 9         NaN          NaN            NaN           <NA>             NaN
#
#   parkingZoneId  fuel  duration
# 0           NaN   NaN       NaN
# 1           NaN   NaN       NaN
# 2           NaN   NaN       NaN
# 3           NaN   NaN       NaN
# 4           NaN   NaN       NaN
# 5           NaN   NaN       NaN
# 6           NaN   NaN       NaN
# 7           NaN   NaN       NaN
# 8           NaN   NaN       NaN
# 9           NaN   NaN       NaN

# %%
df_sim.tail(10)
# Out:
#          time                 type                          vehicle  \
# 37522  216000  LeavingParkingEvent  rideHailVehicle-1482098@default
# 37523  216000  LeavingParkingEvent  rideHailVehicle-5928682@default
# 37524  216000  LeavingParkingEvent  rideHailVehicle-6118448@default
# 37525  216000  LeavingParkingEvent  rideHailVehicle-6119111@default
# 37526  216000  LeavingParkingEvent  rideHailVehicle-2795173@default
# 37527  216000  LeavingParkingEvent   rideHailVehicle-626928@default
# 37528  216000  LeavingParkingEvent  rideHailVehicle-5114439@default
# 37529  216000  LeavingParkingEvent  rideHailVehicle-5139227@default
# 37530  216000  LeavingParkingEvent  rideHailVehicle-5225384@default
# 37531  216000  LeavingParkingEvent  rideHailVehicle-6638376@default
#
#       parkingTaz   chargingPointType  primaryFuelLevel mode currentTourMode  \
# 37522        738  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37523        956  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37524         16  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37525        973  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37526       1269  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37527        598  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37528        675  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37529       1277  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37530        365  homelevel1(1.8|AC)               NaN  NaN             NaN
# 37531       1084  homelevel1(1.8|AC)               NaN  NaN             NaN
#
#       vehicleType  arrivalTime  departureTime linkTravelTime primaryFuelType  \
# 37522         NaN          NaN            NaN           <NA>             NaN
# 37523         NaN          NaN            NaN           <NA>             NaN
# 37524         NaN          NaN            NaN           <NA>             NaN
# 37525         NaN          NaN            NaN           <NA>             NaN
# 37526         NaN          NaN            NaN           <NA>             NaN
# 37527         NaN          NaN            NaN           <NA>             NaN
# 37528         NaN          NaN            NaN           <NA>             NaN
# 37529         NaN          NaN            NaN           <NA>             NaN
# 37530         NaN          NaN            NaN           <NA>             NaN
# 37531         NaN          NaN            NaN           <NA>             NaN
#
#       parkingZoneId  fuel  duration
# 37522           NaN   NaN       NaN
# 37523           NaN   NaN       NaN
# 37524           NaN   NaN       NaN
# 37525           NaN   NaN       NaN
# 37526           NaN   NaN       NaN
# 37527           NaN   NaN       NaN
# 37528           NaN   NaN       NaN
# 37529           NaN   NaN       NaN
# 37530           NaN   NaN       NaN
# 37531           NaN   NaN       NaN

# %%
# choose new rows with events which are interesting and delte df_sim
df_sim_new = df_sim.loc[
    df_sim['type'].isin(['RefuelSessionEvent', 'ChargingPlugOutEvent', 'ChargingPlugInEvent']) &
    df_sim['chargingPointType'].str.contains('DC', na=False)
    , : ]
#del df_sim

# %%
#repartion to save storage. partion_size might be expensive
print("old number of partitions: " + str(df_sim_new.npartitions))
df_sim_new = df_sim_new.repartition(partition_size="100MB").persist() # might be expensive, can put also npartitions # added persist to let this stay in memory
#df_sim_new.compute()
print("new number of partitions: " + str(df_sim_new.npartitions))
df_sim_new = df_sim_new.set_index("time")
df_sim_new.info()
#df_sim_new.head(16)
# Out:
# old number of partitions: 257
# new number of partitions: 1
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 15 entries, type to duration
# dtypes: category(8), float64(5), string(2)

# %%
# print out number of rows
df_sim_new.shape[0].compute()
# Out:
# 2550

# %%
df_sim_new.tail(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30676\3700273118.py in <module>
# ----> 1 df_sim_new.tail(10).compute()
#
# ~\anaconda3\envs\py_btms_controller\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'compute'

# %%
#save data to csv. parquet might be better, but need to downgrade python for that.
df_sim_new.to_csv('test_data/beam1/beam1-*.csv')
# Out:
# ['c:/Users/akaju/Documents/GitHub/xfc-btms-saev-controller/test_data/beam1/beam1-0.csv']
